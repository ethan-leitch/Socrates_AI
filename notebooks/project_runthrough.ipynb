# %% [markdown]
# # Complete runthrough

# %%
from neural_oracle.data_prep import TheFarmer

farmer = TheFarmer()

# %% [markdown]
# ## Tokenisation

# %%
from neural_oracle.oracle import TokeniseBooks

cleaned_books_path = farmer.cleaned_dir
books_path = 
tokeniser = TokeniseBooks()
