# %% [markdown]
# # Complete runthrough

# %%
from socrates_ai.data_prep import TheFarmer

farmer = TheFarmer()

# %%
farmer.clean_dir
# Out:
# '../data/clean_books'

# %% [markdown]
# ## Tokenisation

# %%
from socrates_ai.oracle import TokeniseBooks

books_path = farmer.clean_dir
tokeniser = TokeniseBooks(cleaned_books_path=books_path)
