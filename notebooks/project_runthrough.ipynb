# %% [markdown]
# # Complete runthrough

# %%
from socrates_ai.data_prep import TheFarmer

farmer = TheFarmer()

# %%
farmer.set_data_destination()
# Out:
# Storing cache data at:
# /Users/ethanleitch/Documents/Coding_Projects/Socrates_AI/data/gutenberg_catalog_cache/gutenbergindex.db
# /Users/ethanleitch/Documents/Coding_Projects/Socrates_AI/data/gutenberg_catalog_cache/epub

# %%
farmer.retrieve_gutenberg_books()
# Out:
# Deleting old files
#  Downloading rdf-files.tar.bz2 : [####################]took 37.210198
#  Extracting  rdf-files.tar.bz2 : [###################]]took 465.090764
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 farmer.retrieve_gutenberg_books()
#
# File ~/Documents/Coding_Projects/Socrates_AI/socrates_ai/data_prep.py:47, in TheFarmer.retrieve_gutenberg_books(self)
#      43     print(
#      44         "Cache has already been created ensure .db & epub files are in gutenberg_cataglog_cache "
#      45     )
#      46 else:
# ---> 47     GutenbergCache.create(
#      48         refresh=True,
#      49         download=True,
#      50         unpack=True,
#      51         parse=True,
#      52         cache=True,
#      53         deleteTemp=True,
#      54     )
#      55 self.cache = GutenbergCache.get_cache()
#
# File ~/Documents/Coding_Projects/Socrates_AI/.venv/lib/python3.11/site-packages/gutenbergpy/gutenbergcache.py:62, in GutenbergCache.create(**kwargs)
#      60 t0 = time.time()
#      61 parser = RdfParser()
# ---> 62 result = parser.do()
#      63 print('RDF PARSING took ' + str(time.time() - t0))
#      65 if cache:
#
# File ~/Documents/Coding_Projects/Socrates_AI/.venv/lib/python3.11/site-packages/gutenbergpy/parse/rdfparser.py:37, in RdfParser.do()
#      33 result.field_sets[Fields.PUBLISHER] = ParseItem(xpath =['//dcterms:publisher/text()'])
#      34 result.field_sets[Fields.RIGHTS]    = ParseItem( xpath =['//dcterms:rights/text()'])
# ---> 37 dirs  =  [d for d in listdir(GutenbergCacheSettings.CACHE_RDF_UNPACK_DIRECTORY) if not d.startswith("DELETE")]
#      38 total = len(dirs)
#      40 for idx, dir in enumerate(dirs):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/ethanleitch/Documents/Coding_Projects/Socrates_AI/data/gutenberg_catalog_cache/epub'

# %%
farmer.farm_philosophy_books()

# %%
farmer.clean_books()

# %%
farmer.check_cleaned_data()

# %% [markdown]
# ## Tokenisation

# %%
from socrates_ai.oracle import Translator

books_path = farmer.clean_dir
translator = Translator(cleaned_books_path=books_path)

# %%
translator.train_tokeniser()
# Out:
# Training on 50 files
#
#
#
# Trained vocab size: 8000
# Saved to ../data/tokenizer.json

# %%
oracle_tokens = translator.load_tokeniser()

# %%
translator.test_tokeniser(tokeniser=oracle_tokens)
# Out:
# 60 characters -> 13 tokens
#
# ids:    [7220, 4431, 572, 2239, 29, 178, 2617, 6057, 2641, 184, 178, 512, 17]
# pieces: ['ĠAlso', 'Ġspr', 'ach', 'ĠZarathustra', ':', 'Ġthe', 'Ġeternal', 'Ġrecur', 'rence', 'Ġof', 'Ġthe', 'Ġsame', '.']
#
# decoded round-trip:  Also sprach Zarathustra: the eternal recurrence of the same.
# round-trip matches original: False
